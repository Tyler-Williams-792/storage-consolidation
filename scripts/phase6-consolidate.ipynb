# %%
import os
fio = '/run/user/1000/gvfs/smb-share:server=truenas.local,share=konasmb/Staging_Fio'
kona = '/run/user/1000/gvfs/smb-share:server=truenas.local,share=kona/SynologyDrive/Kona'
# Out:
# '/home/tytrater/new/Storage_Consolidation'
